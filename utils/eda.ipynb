# %%
import pandas as pd

# %%
data = pd.read_csv("../data/input/roundtrip.csv")

# %%
print(len(data[data['gender']=='male']))
print(len(data[data['gender']=='female']))
print(len(data[data['gender']=='neutral']))
# Out:
# 333
# 313
# 354

# %%
print(len(data[data['treatment']=='positive']))
print(len(data[data['treatment']=='negative']))
# Out:
# 487
# 513
